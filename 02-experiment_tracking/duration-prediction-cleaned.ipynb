# %%
# !python -V
# Out:
# Python 3.9.23

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.metrics import root_mean_squared_error
import pickle

# %%
# incorporate mlflow
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# 2025/06/23 20:53:50 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/06/23 20:53:50 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# <Experiment: artifact_location='/workspaces/mlops-zoomcamp/02-experiment_tracking/mlruns/1', creation_time=1750216104664, experiment_id='1', last_update_time=1750216104664, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
# compile to a function -- read the data

def read_dataframe(filename):
    df = pd.read_parquet(filename)
    df['diff'] = df.lpep_dropoff_datetime -df.lpep_pickup_datetime
    df['duration'] = df['diff'].dt.total_seconds()/60
    df = df[(df.duration >=1)&(df.duration <=60)]
    categorical = ['PULocationID','DOLocationID'] # pick the categorical features that might be useful to predict duration
    df[categorical] = df[categorical].astype('str')
    return df

# %%
df_train = read_dataframe("data/green_tripdata_2021-01.parquet")
df_val = read_dataframe("data/green_tripdata_2021-02.parquet")

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
# exploring new features to better predict the duration
# e.g. pickup-dropoff pair
df_train['PU_DO'] = df_train['PULocationID'] + '_'+ df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_'+ df_val['DOLocationID']

# %%
categorical = ['PU_DO'] # ['PULocationID','DOLocationID'] 
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical+numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts) 

val_dicts = df_val[categorical+numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts) # for validation we don't run fit_transform

# %%
target ='duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression() # create an instance/object
lr.fit(X_train, y_train)

y_val_pred = lr.predict(X_val) # apply the model trained on train-set on the validation set

root_mean_squared_error(y_val, y_val_pred)
# Out:
# 7.758715209663881

# %%
# try Ridge
rd = Ridge(alpha=10)

rd.fit(X_train, y_train)

y_pred = rd.predict(X_train)
y_val_pred = rd.predict(X_val)

print('Training RMSE is', root_mean_squared_error(y_train, y_pred))
print('Validation RMSE is', root_mean_squared_error(y_val, y_val_pred))
# Out:
# Training RMSE is 7.6660279773989375
# Validation RMSE is 8.846837413677452

# %% [markdown]
# #### suppose we want to keep the linear regression (baseline) model

# %%
with open('models/lin_reg.bin', 'wb') as f_out: # mode = 'wb' (write binary)
    pickle.dump((dv, lr), f_out)

# %%
# baseline -- linear regression
# then try Lasso

# now modify to save experiments using mlflow

with mlflow.start_run():

    mlflow.set_tag("developer","CS")
    mlflow.log_param("train-data-path","data/green_tripdata_2021-01.parquet") # including hyperparameters
    mlflow.log_param("valid-data-path","data/green_tripdata_2021-02.parquet")

    #alpha: the penalty term that denotes the amount of shrinkage that will be implemented in the equation
    # when alpha = 0 the model is equivalent to a linear regression model
    # larger alpha value penalizes the optimization function 

    #alpha = 0.01
    #alpha = 0.1

    #mlflow.log_param("alpha", alpha)

    #ls = Lasso(alpha)
    # ls = Lasso(alpha = 0.01) # adjust alpha to see fitting performance
    #ls.fit(X_train, y_train)

    #y_pred = ls.predict(X_train)
    #y_val_pred = ls.predict(X_val)

    lr = LinearRegression() 
    lr.fit(X_train, y_train)
    
    y_pred = lr.predict(X_train)
    y_val_pred = lr.predict(X_val) 

   # print('Training RMSE is', root_mean_squared_error(y_train, y_pred))
   # print('Validation RMSE is', root_mean_squared_error(y_val, y_val_pred))
    rmse_train = root_mean_squared_error(y_train, y_pred)
    rmse_val = root_mean_squared_error(y_val, y_val_pred)

    mlflow.log_metrics({
        "rmse_train":rmse_train, 
        "rmse_val": rmse_val
        })
    
    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle") 
    # local_path: where i stored the model locally using picle dump
    # artifact_path: where the mlflow will save the model

# %%
# add this before importing xgboost to avoid crashes
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
# try xgboost
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
mlflow.xgboost.autolog() # call mlflow.autolog() before creating dataset or training model

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model","xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid,"validation")],
            early_stopping_rounds=10 # instead of 50, which is used by the instructor
        )
        y_pred=booster.predict(train)
        y_val_pred=booster.predict(valid)

        rmse_train = root_mean_squared_error(y_train, y_pred)
        rmse_val = root_mean_squared_error(y_val, y_val_pred)

        mlflow.log_metrics({
        "rmse_train":rmse_train, 
        "rmse_val": rmse_val
        })
    return {'loss':rmse_val,'status':STATUS_OK} # loss must be a string or a number

search_space = {
'max_depth': scope.int(hp.quniform('max_depth',4,100,1)),
'learning_rate': hp.loguniform('learning_rate',-3,0), # [exp(-3), exp(0)], which is [0.05, 1]
'reg_alpha':hp.loguniform('reg_alpha',-5,-1),
'reg_lambda':hp.loguniform('reg_lambda',-6,-1),
'min_child_weight':hp.loguniform('min_child_weight',-1,3),
'objective':'reg:linear',
'seed':42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()

)
# Out:
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# /opt/conda/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [22:45:16] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:7.16223
# [1]	validation-rmse:6.67195
# [2]	validation-rmse:6.59432
# [3]	validation-rmse:6.56282
# [4]	validation-rmse:6.55057
# [5]	validation-rmse:6.54149
# [6]	validation-rmse:6.52071
# [7]	validation-rmse:6.51534
# [8]	validation-rmse:6.50995
# [9]	validation-rmse:6.50652
# [10]	validation-rmse:6.50377
# [11]	validation-rmse:6.49813
# [12]	validation-rmse:6.49549
# [13]	validation-rmse:6.49213
# [14]	validation-rmse:6.49045
# [15]	validation-rmse:6.48916
# [16]	validation-rmse:6.48721
# [17]	validation-rmse:6.48440
# [18]	validation-rmse:6.48157
# [19]	validation-rmse:6.47962
# [20]	validation-rmse:6.47826
# [21]	validation-rmse:6.47639
# [22]	validation-rmse:6.47564
# [23]	validation-rmse:6.47508
# [24]	validation-rmse:6.47436
# [25]	validation-rmse:6.47337
# [26]	validation-rmse:6.47241
# [27]	validation-rmse:6.47273
# [28]	validation-rmse:6.47147
# [29]	validation-rmse:6.47056
# [30]	validation-rmse:6.47039
# [31]	validation-rmse:6.47073
# [32]	validation-rmse:6.47031
# [33]	validation-rmse:6.47016
# [34]	validation-rmse:6.46928
# [35]	validation-rmse:6.46889
# [36]	validation-rmse:6.46940
# [37]	validation-rmse:6.46969
# [38]	validation-rmse:6.46907
# [39]	validation-rmse:6.46871
# [40]	validation-rmse:6.46750
# [41]	validation-rmse:6.46683
# [42]	validation-rmse:6.46638
# [43]	validation-rmse:6.46665
# [44]	validation-rmse:6.46673
# [45]	validation-rmse:6.46616
# [46]	validation-rmse:6.46514
# [47]	validation-rmse:6.46472
# [48]	validation-rmse:6.46584
# [49]	validation-rmse:6.46596
# [50]	validation-rmse:6.46559
# [51]	validation-rmse:6.46493
# [52]	validation-rmse:6.46403
# [53]	validation-rmse:6.46549
# [54]	validation-rmse:6.46492
# [55]	validation-rmse:6.46498
# [56]	validation-rmse:6.46456
# [57]	validation-rmse:6.46395
# [58]	validation-rmse:6.46371
# [59]	validation-rmse:6.46294
# [60]	validation-rmse:6.46248
# [61]	validation-rmse:6.46206
# [62]	validation-rmse:6.46165
# [63]	validation-rmse:6.46119
# [64]	validation-rmse:6.46182
# [65]	validation-rmse:6.46196
# [66]	validation-rmse:6.46085
# [67]	validation-rmse:6.46153
# [68]	validation-rmse:6.46175
# [69]	validation-rmse:6.46123
# [70]	validation-rmse:6.46175
# [71]	validation-rmse:6.46032
# [72]	validation-rmse:6.46093
# [73]	validation-rmse:6.46090
# [74]	validation-rmse:6.46066
# [75]	validation-rmse:6.46010
# [76]	validation-rmse:6.46015
# [77]	validation-rmse:6.46009
# [78]	validation-rmse:6.46001
# [79]	validation-rmse:6.45939
# [80]	validation-rmse:6.45847
# [81]	validation-rmse:6.45929
# [82]	validation-rmse:6.45873
# [83]	validation-rmse:6.45814
# [84]	validation-rmse:6.45760
# [85]	validation-rmse:6.45720
# [86]	validation-rmse:6.45731
# [87]	validation-rmse:6.45761
# [88]	validation-rmse:6.45757
# [89]	validation-rmse:6.45692
# [90]	validation-rmse:6.45716
# [91]	validation-rmse:6.45687
# [92]	validation-rmse:6.45724
# [93]	validation-rmse:6.45631
# [94]	validation-rmse:6.45638
# [95]	validation-rmse:6.45674
# [96]	validation-rmse:6.45550
# [97]	validation-rmse:6.45605
# [98]	validation-rmse:6.45627
# [99]	validation-rmse:6.45708
# [100]	validation-rmse:6.45709
# [101]	validation-rmse:6.45738
# [102]	validation-rmse:6.45667
# [103]	validation-rmse:6.45704
# [104]	validation-rmse:6.45687
# [105]	validation-rmse:6.45706
# [106]	validation-rmse:6.45724
# [107]	validation-rmse:6.45674
# [108]	validation-rmse:6.45761
# [109]	validation-rmse:6.45852
# [110]	validation-rmse:6.45982
# [111]	validation-rmse:6.45843
# [112]	validation-rmse:6.45849
# [113]	validation-rmse:6.45817
# [114]	validation-rmse:6.45731
# [115]	validation-rmse:6.45826
# [116]	validation-rmse:6.45814
# [117]	validation-rmse:6.45783
# [118]	validation-rmse:6.45762
# [119]	validation-rmse:6.45756
# [120]	validation-rmse:6.45828
# [121]	validation-rmse:6.45886
# [122]	validation-rmse:6.45984
# [123]	validation-rmse:6.45948
# [124]	validation-rmse:6.45863
# [125]	validation-rmse:6.45951
# [126]	validation-rmse:6.45933
# [127]	validation-rmse:6.45950
# [128]	validation-rmse:6.45965
# [129]	validation-rmse:6.45948
# [130]	validation-rmse:6.45941
# [131]	validation-rmse:6.46027
# [132]	validation-rmse:6.46050
# [133]	validation-rmse:6.46065
# [134]	validation-rmse:6.46096
# [135]	validation-rmse:6.46147
# [136]	validation-rmse:6.46160
# [137]	validation-rmse:6.46211
# [138]	validation-rmse:6.46245
# [139]	validation-rmse:6.46237
# [140]	validation-rmse:6.46270
# [141]	validation-rmse:6.46210
# [142]	validation-rmse:6.46233
# [143]	validation-rmse:6.46272
# [144]	validation-rmse:6.46252
# [145]	validation-rmse:6.46261
# [146]	validation-rmse:6.46308
#   2%|▏         | 1/50 [00:44<35:57, 44.03s/trial, best loss: 6.4630797473875745]
# /opt/conda/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [22:46:00] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:9.83771
# [1]	validation-rmse:8.43321
# [2]	validation-rmse:7.63906
# [3]	validation-rmse:7.20078
# [4]	validation-rmse:6.95922
# [5]	validation-rmse:6.82344
# [6]	validation-rmse:6.73585
# [7]	validation-rmse:6.68452
# [8]	validation-rmse:6.65080
# [9]	validation-rmse:6.62794
# [10]	validation-rmse:6.61318
# [11]	validation-rmse:6.60104
# [12]	validation-rmse:6.58849
# [13]	validation-rmse:6.58212
# [14]	validation-rmse:6.57517
# [15]	validation-rmse:6.57074
# [16]	validation-rmse:6.56951
# [17]	validation-rmse:6.56735
# [18]	validation-rmse:6.56602
# [19]	validation-rmse:6.56480
# [20]	validation-rmse:6.56066
# [21]	validation-rmse:6.55965
# [22]	validation-rmse:6.55835
# [23]	validation-rmse:6.55733
# [24]	validation-rmse:6.55586
# [25]	validation-rmse:6.55514
# [26]	validation-rmse:6.55421
# [27]	validation-rmse:6.55300
# [28]	validation-rmse:6.54964
# [29]	validation-rmse:6.54906
# [30]	validation-rmse:6.54660
# [31]	validation-rmse:6.54591
# [32]	validation-rmse:6.54416
# [33]	validation-rmse:6.54344
# [34]	validation-rmse:6.54287
# [35]	validation-rmse:6.54127
# [36]	validation-rmse:6.53982
# [37]	validation-rmse:6.53900
# [38]	validation-rmse:6.53860
# [39]	validation-rmse:6.53778
# [40]	validation-rmse:6.53731
# [41]	validation-rmse:6.53668
# [42]	validation-rmse:6.53537
# [43]	validation-rmse:6.53435
# [44]	validation-rmse:6.53433
# [45]	validation-rmse:6.53265
# [46]	validation-rmse:6.53223
# [47]	validation-rmse:6.53103
# [48]	validation-rmse:6.53034
# [49]	validation-rmse:6.53025
# [50]	validation-rmse:6.52980
# [51]	validation-rmse:6.52911
# [52]	validation-rmse:6.52866
# [53]	validation-rmse:6.52820
# [54]	validation-rmse:6.52751
# [55]	validation-rmse:6.52725
# [56]	validation-rmse:6.52646
# [57]	validation-rmse:6.52629
# [58]	validation-rmse:6.52583
# [59]	validation-rmse:6.52574
# [60]	validation-rmse:6.52583
# [61]	validation-rmse:6.52548
# [62]	validation-rmse:6.52517
# [63]	validation-rmse:6.52492
# [64]	validation-rmse:6.52456
# [65]	validation-rmse:6.52411
# [66]	validation-rmse:6.52361
# [67]	validation-rmse:6.52321
# [68]	validation-rmse:6.52281
# [69]	validation-rmse:6.52238
# [70]	validation-rmse:6.52220
# [71]	validation-rmse:6.52199
# [72]	validation-rmse:6.52149
# [73]	validation-rmse:6.52117
# [74]	validation-rmse:6.52053
# [75]	validation-rmse:6.52035
# [76]	validation-rmse:6.52004
# [77]	validation-rmse:6.51978
# [78]	validation-rmse:6.51987
# [79]	validation-rmse:6.51908
# [80]	validation-rmse:6.51920
# [81]	validation-rmse:6.51894
# [82]	validation-rmse:6.51876
# [83]	validation-rmse:6.51855
# [84]	validation-rmse:6.51823
# [85]	validation-rmse:6.51813
# [86]	validation-rmse:6.51790
# [87]	validation-rmse:6.51751
# [88]	validation-rmse:6.51735
# [89]	validation-rmse:6.51731
# [90]	validation-rmse:6.51699
# [91]	validation-rmse:6.51678
# [92]	validation-rmse:6.51656
# [93]	validation-rmse:6.51643
# [94]	validation-rmse:6.51646
# [95]	validation-rmse:6.51639
# [96]	validation-rmse:6.51605
# [97]	validation-rmse:6.51608
# [98]	validation-rmse:6.51604
# [99]	validation-rmse:6.51569
# [100]	validation-rmse:6.51553
# [101]	validation-rmse:6.51543
# [102]	validation-rmse:6.51554
# [103]	validation-rmse:6.51541
# [104]	validation-rmse:6.51535
# [105]	validation-rmse:6.51535
# [106]	validation-rmse:6.51482
# [107]	validation-rmse:6.51472
# [108]	validation-rmse:6.51464
# [109]	validation-rmse:6.51446
# [110]	validation-rmse:6.51421
# [111]	validation-rmse:6.51402
# [112]	validation-rmse:6.51389
# [113]	validation-rmse:6.51393
# [114]	validation-rmse:6.51336
# [115]	validation-rmse:6.51336
# [116]	validation-rmse:6.51342
# [117]	validation-rmse:6.51310
# [118]	validation-rmse:6.51300
# [119]	validation-rmse:6.51308
# [120]	validation-rmse:6.51259
# [121]	validation-rmse:6.51253
# [122]	validation-rmse:6.51224
# [123]	validation-rmse:6.51187
# [124]	validation-rmse:6.51163
# [125]	validation-rmse:6.51161
# [126]	validation-rmse:6.51116
# [127]	validation-rmse:6.51105
# [128]	validation-rmse:6.51094
# [129]	validation-rmse:6.51061
# [130]	validation-rmse:6.51059
# [131]	validation-rmse:6.51041
# [132]	validation-rmse:6.51031
# [133]	validation-rmse:6.51020
# [134]	validation-rmse:6.51026
# [135]	validation-rmse:6.51003
# [136]	validation-rmse:6.51000
# [137]	validation-rmse:6.51009
# [138]	validation-rmse:6.51008
# [139]	validation-rmse:6.51006
# [140]	validation-rmse:6.51013
# [141]	validation-rmse:6.50997
# [142]	validation-rmse:6.50974
# [143]	validation-rmse:6.50951
# [144]	validation-rmse:6.50952
# [145]	validation-rmse:6.50948
# [146]	validation-rmse:6.50964
# [147]	validation-rmse:6.50923
# [148]	validation-rmse:6.50912
# [149]	validation-rmse:6.50923
# [150]	validation-rmse:6.50904
# [151]	validation-rmse:6.50909
# [152]	validation-rmse:6.50894
# [153]	validation-rmse:6.50893
# [154]	validation-rmse:6.50853
# [155]	validation-rmse:6.50879
# [156]	validation-rmse:6.50877
# [157]	validation-rmse:6.50836
# [158]	validation-rmse:6.50860
# [159]	validation-rmse:6.50842
# [160]	validation-rmse:6.50832
# [161]	validation-rmse:6.50776
# [162]	validation-rmse:6.50767
# [163]	validation-rmse:6.50773
# [164]	validation-rmse:6.50766
# [165]	validation-rmse:6.50768
# [166]	validation-rmse:6.50710
# [167]	validation-rmse:6.50718
# [168]	validation-rmse:6.50718
# [169]	validation-rmse:6.50715
# [170]	validation-rmse:6.50698
# [171]	validation-rmse:6.50653
# [172]	validation-rmse:6.50674
# [173]	validation-rmse:6.50638
# [174]	validation-rmse:6.50666
# [175]	validation-rmse:6.50660
# [176]	validation-rmse:6.50618
# [177]	validation-rmse:6.50622
# [178]	validation-rmse:6.50656
# [179]	validation-rmse:6.50645
# [180]	validation-rmse:6.50633
# [181]	validation-rmse:6.50599
# [182]	validation-rmse:6.50607
# [183]	validation-rmse:6.50597
# [184]	validation-rmse:6.50585
# [185]	validation-rmse:6.50565
# [186]	validation-rmse:6.50491
# [187]	validation-rmse:6.50511
# [188]	validation-rmse:6.50514
# [189]	validation-rmse:6.50518
# [190]	validation-rmse:6.50532
# [191]	validation-rmse:6.50527
# [192]	validation-rmse:6.50526
# [193]	validation-rmse:6.50503
# [194]	validation-rmse:6.50502
# [195]	validation-rmse:6.50471
# [196]	validation-rmse:6.50469
# [197]	validation-rmse:6.50486
# [198]	validation-rmse:6.50459
# [199]	validation-rmse:6.50460
# [200]	validation-rmse:6.50444
# [201]	validation-rmse:6.50441
# [202]	validation-rmse:6.50427
# [203]	validation-rmse:6.50404
# [204]	validation-rmse:6.50399
# [205]	validation-rmse:6.50350
# [206]	validation-rmse:6.50356
# [207]	validation-rmse:6.50365
# [208]	validation-rmse:6.50373
# [209]	validation-rmse:6.50359
# [210]	validation-rmse:6.50360
# [211]	validation-rmse:6.50348
# [212]	validation-rmse:6.50331
# [213]	validation-rmse:6.50296
# [214]	validation-rmse:6.50290
# [215]	validation-rmse:6.50267
# [216]	validation-rmse:6.50244
# [217]	validation-rmse:6.50252
# [218]	validation-rmse:6.50238
# [219]	validation-rmse:6.50226
# [220]	validation-rmse:6.50245
# [221]	validation-rmse:6.50260
# [222]	validation-rmse:6.50222
# [223]	validation-rmse:6.50242
# [224]	validation-rmse:6.50248
# [225]	validation-rmse:6.50254
# [226]	validation-rmse:6.50254
# [227]	validation-rmse:6.50255
# [228]	validation-rmse:6.50240
# [229]	validation-rmse:6.50220
# [230]	validation-rmse:6.50218
# [231]	validation-rmse:6.50203
# [232]	validation-rmse:6.50192
# [233]	validation-rmse:6.50208
# [234]	validation-rmse:6.50168
# [235]	validation-rmse:6.50162
# [236]	validation-rmse:6.50142
# [237]	validation-rmse:6.50148
# [238]	validation-rmse:6.50138
# [239]	validation-rmse:6.50111
# [240]	validation-rmse:6.50112
# [241]	validation-rmse:6.50116
# [242]	validation-rmse:6.50125
# [243]	validation-rmse:6.50126
# [244]	validation-rmse:6.50106
# [245]	validation-rmse:6.50107
# [246]	validation-rmse:6.50101
# [247]	validation-rmse:6.50065
# [248]	validation-rmse:6.50078
# [249]	validation-rmse:6.50089
# [250]	validation-rmse:6.50091
# [251]	validation-rmse:6.50061
# [252]	validation-rmse:6.50079
# [253]	validation-rmse:6.50078
# [254]	validation-rmse:6.50058
# [255]	validation-rmse:6.50041
# [256]	validation-rmse:6.50075
# [257]	validation-rmse:6.50087
# [258]	validation-rmse:6.50110
# [259]	validation-rmse:6.50101
# [260]	validation-rmse:6.50093
# [261]	validation-rmse:6.50119
# [262]	validation-rmse:6.50127
# [263]	validation-rmse:6.50092
# [264]	validation-rmse:6.50063
# [265]	validation-rmse:6.50074
# [266]	validation-rmse:6.50048
# [267]	validation-rmse:6.50030
# [268]	validation-rmse:6.50038
# [269]	validation-rmse:6.50071
# [270]	validation-rmse:6.50085
# [271]	validation-rmse:6.50082
# [272]	validation-rmse:6.50027
# [273]	validation-rmse:6.50041
# [274]	validation-rmse:6.50050
# [275]	validation-rmse:6.50042
# [276]	validation-rmse:6.50045
# [277]	validation-rmse:6.50021
# [278]	validation-rmse:6.50029
# [279]	validation-rmse:6.50038
# [280]	validation-rmse:6.50047
# [281]	validation-rmse:6.50046
# [282]	validation-rmse:6.50044
# [283]	validation-rmse:6.50029
# [284]	validation-rmse:6.50027
# [285]	validation-rmse:6.50027
# [286]	validation-rmse:6.50024
# [287]	validation-rmse:6.50026
# [288]	validation-rmse:6.50011
# [289]	validation-rmse:6.50009
# [290]	validation-rmse:6.50007
# [291]	validation-rmse:6.49990
# [292]	validation-rmse:6.49976
# [293]	validation-rmse:6.49977
# [294]	validation-rmse:6.49966
# [295]	validation-rmse:6.49990
# [296]	validation-rmse:6.49976
# [297]	validation-rmse:6.49973
# [298]	validation-rmse:6.49951
# [299]	validation-rmse:6.49945
# [300]	validation-rmse:6.49959
# [301]	validation-rmse:6.49948
# [302]	validation-rmse:6.49938
# [303]	validation-rmse:6.49931
# [304]	validation-rmse:6.49932
# [305]	validation-rmse:6.49933
# [306]	validation-rmse:6.49926
# [307]	validation-rmse:6.49922
# [308]	validation-rmse:6.49906
# [309]	validation-rmse:6.49889
# [310]	validation-rmse:6.49901
# [311]	validation-rmse:6.49904
# [312]	validation-rmse:6.49893
# [313]	validation-rmse:6.49874
# [314]	validation-rmse:6.49867
# [315]	validation-rmse:6.49883
# [316]	validation-rmse:6.49887
# [317]	validation-rmse:6.49893
# [318]	validation-rmse:6.49870
# [319]	validation-rmse:6.49881
# [320]	validation-rmse:6.49871
# [321]	validation-rmse:6.49863
# [322]	validation-rmse:6.49877
# [323]	validation-rmse:6.49873
# [324]	validation-rmse:6.49869
# [325]	validation-rmse:6.49886
# [326]	validation-rmse:6.49879
# [327]	validation-rmse:6.49878
# [328]	validation-rmse:6.49863
# [329]	validation-rmse:6.49872
# [330]	validation-rmse:6.49878
# [331]	validation-rmse:6.49873
# [332]	validation-rmse:6.49872
# [333]	validation-rmse:6.49863
# [334]	validation-rmse:6.49866
# [335]	validation-rmse:6.49866
# [336]	validation-rmse:6.49897
# [337]	validation-rmse:6.49862
# [338]	validation-rmse:6.49884
# [339]	validation-rmse:6.49870
# [340]	validation-rmse:6.49861
# [341]	validation-rmse:6.49873
# [342]	validation-rmse:6.49863
# [343]	validation-rmse:6.49861
# [344]	validation-rmse:6.49853
# [345]	validation-rmse:6.49854
# [346]	validation-rmse:6.49854
# [347]	validation-rmse:6.49872
# [348]	validation-rmse:6.49863
# [349]	validation-rmse:6.49872
# [350]	validation-rmse:6.49861
# [351]	validation-rmse:6.49864
# [352]	validation-rmse:6.49861
# [353]	validation-rmse:6.49860
# [354]	validation-rmse:6.49835
# [355]	validation-rmse:6.49851
# [356]	validation-rmse:6.49844
# [357]	validation-rmse:6.49836
# [358]	validation-rmse:6.49812
# [359]	validation-rmse:6.49829
# [360]	validation-rmse:6.49804
# [361]	validation-rmse:6.49792
# [362]	validation-rmse:6.49809
# [363]	validation-rmse:6.49827
# [364]	validation-rmse:6.49831
# [365]	validation-rmse:6.49832
# [366]	validation-rmse:6.49815
# [367]	validation-rmse:6.49803
# [368]	validation-rmse:6.49797
# [369]	validation-rmse:6.49806
# [370]	validation-rmse:6.49800
# [371]	validation-rmse:6.49796
# [372]	validation-rmse:6.49795
# [373]	validation-rmse:6.49793
# [374]	validation-rmse:6.49792
# [375]	validation-rmse:6.49765
# [376]	validation-rmse:6.49760
# [377]	validation-rmse:6.49756
# [378]	validation-rmse:6.49767
# [379]	validation-rmse:6.49775
# [380]	validation-rmse:6.49772
# [381]	validation-rmse:6.49780
# [382]	validation-rmse:6.49785
# [383]	validation-rmse:6.49780
# [384]	validation-rmse:6.49771
# [385]	validation-rmse:6.49759
# [386]	validation-rmse:6.49757
# [387]	validation-rmse:6.49754
# [388]	validation-rmse:6.49753
# [389]	validation-rmse:6.49785
# [390]	validation-rmse:6.49779
# [391]	validation-rmse:6.49785
# [392]	validation-rmse:6.49790
# [393]	validation-rmse:6.49783
# [394]	validation-rmse:6.49787
# [395]	validation-rmse:6.49797
# [396]	validation-rmse:6.49793
# [397]	validation-rmse:6.49787
# [398]	validation-rmse:6.49784
# [399]	validation-rmse:6.49784
# [400]	validation-rmse:6.49792
# [401]	validation-rmse:6.49799
# [402]	validation-rmse:6.49775
# [403]	validation-rmse:6.49785
# [404]	validation-rmse:6.49773
# [405]	validation-rmse:6.49757
# [406]	validation-rmse:6.49756
# [407]	validation-rmse:6.49754
# [408]	validation-rmse:6.49749
# [409]	validation-rmse:6.49752
# [410]	validation-rmse:6.49761
# [411]	validation-rmse:6.49769
# [412]	validation-rmse:6.49753
# [413]	validation-rmse:6.49761
# [414]	validation-rmse:6.49745
# [415]	validation-rmse:6.49751
# [416]	validation-rmse:6.49763
# [417]	validation-rmse:6.49753
# [418]	validation-rmse:6.49769
# [419]	validation-rmse:6.49768
# [420]	validation-rmse:6.49774
# [421]	validation-rmse:6.49756
# [422]	validation-rmse:6.49739
# [423]	validation-rmse:6.49732
# [424]	validation-rmse:6.49729
# [425]	validation-rmse:6.49749
# [426]	validation-rmse:6.49749
# [427]	validation-rmse:6.49709
# [428]	validation-rmse:6.49705
# [429]	validation-rmse:6.49728
# [430]	validation-rmse:6.49729
# [431]	validation-rmse:6.49729
# [432]	validation-rmse:6.49716
# [433]	validation-rmse:6.49711
# [434]	validation-rmse:6.49712
# [435]	validation-rmse:6.49709
# [436]	validation-rmse:6.49713
# [437]	validation-rmse:6.49734
# [438]	validation-rmse:6.49751
# [439]	validation-rmse:6.49748
# [440]	validation-rmse:6.49737
# [441]	validation-rmse:6.49752
# [442]	validation-rmse:6.49749
# [443]	validation-rmse:6.49756
# [444]	validation-rmse:6.49748
# [445]	validation-rmse:6.49750
# [446]	validation-rmse:6.49757
# [447]	validation-rmse:6.49740
# [448]	validation-rmse:6.49741
# [449]	validation-rmse:6.49735
# [450]	validation-rmse:6.49720
# [451]	validation-rmse:6.49736
# [452]	validation-rmse:6.49746
# [453]	validation-rmse:6.49748
# [454]	validation-rmse:6.49742
# [455]	validation-rmse:6.49748
# [456]	validation-rmse:6.49772
# [457]	validation-rmse:6.49794
# [458]	validation-rmse:6.49791
# [459]	validation-rmse:6.49792
# [460]	validation-rmse:6.49792
# [461]	validation-rmse:6.49779
# [462]	validation-rmse:6.49776
# [463]	validation-rmse:6.49758
# [464]	validation-rmse:6.49749
# [465]	validation-rmse:6.49752
# [466]	validation-rmse:6.49746
# [467]	validation-rmse:6.49734
# [468]	validation-rmse:6.49734
# [469]	validation-rmse:6.49735
# [470]	validation-rmse:6.49748
# [471]	validation-rmse:6.49750
# [472]	validation-rmse:6.49764
# [473]	validation-rmse:6.49775
# [474]	validation-rmse:6.49772
# [475]	validation-rmse:6.49759
# [476]	validation-rmse:6.49759
# [477]	validation-rmse:6.49751
#   4%|▍         | 2/50 [02:39<1:08:49, 86.03s/trial, best loss: 6.4630797473875745]
# /opt/conda/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [22:47:56] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:9.83313
# [1]	validation-rmse:8.41097
# ...
# [92]	validation-rmse:6.65044
# [93]	validation-rmse:6.65017
# [94]	validation-rmse:6.65022
# [95]	validation-rmse:6.65025
# [96]	validation-rmse:6.64989
# [97]	validation-rmse:6.64986
# [98]	validation-rmse:6.64957
# [99]	validation-rmse:6.64902
# [100]	validation-rmse:6.64897
# [101]	validation-rmse:6.64879
# [102]	validation-rmse:6.64860
# [103]	validation-rmse:6.64848
# [104]	validation-rmse:6.64824
# [105]	validation-rmse:6.64822
# [106]	validation-rmse:6.64786
# [107]	validation-rmse:6.64784
# [108]	validation-rmse:6.64790
# [109]	validation-rmse:6.64779
# [110]	validation-rmse:6.64769
# [111]	validation-rmse:6.64780
# [112]	validation-rmse:6.64748
# [113]	validation-rmse:6.64712
# [114]	validation-rmse:6.64750
# [115]	validation-rmse:6.64766
# [116]	validation-rmse:6.64767
# [117]	validation-rmse:6.64755
# [118]	validation-rmse:6.64765
# [119]	validation-rmse:6.64732
# [120]	validation-rmse:6.64737
# [121]	validation-rmse:6.64735
# [122]	validation-rmse:6.64739
# [123]	validation-rmse:6.64748
# [124]	validation-rmse:6.64699
# [125]	validation-rmse:6.64676
# [126]	validation-rmse:6.64628
# [127]	validation-rmse:6.64647
# [128]	validation-rmse:6.64628
# [129]	validation-rmse:6.64639
# [130]	validation-rmse:6.64599
# [131]	validation-rmse:6.64633
# [132]	validation-rmse:6.64635
# [133]	validation-rmse:6.64618
# [134]	validation-rmse:6.64618
# [135]	validation-rmse:6.64583
# [136]	validation-rmse:6.64580
# [137]	validation-rmse:6.64567
# [138]	validation-rmse:6.64605
# [139]	validation-rmse:6.64572
# [140]	validation-rmse:6.64562
# [141]	validation-rmse:6.64519
# [142]	validation-rmse:6.64517
# [143]	validation-rmse:6.64528
# [144]	validation-rmse:6.64512
# [145]	validation-rmse:6.64532
# [146]	validation-rmse:6.64522
# [147]	validation-rmse:6.64531
# [148]	validation-rmse:6.64526
# [149]	validation-rmse:6.64554
# [150]	validation-rmse:6.64497
# [151]	validation-rmse:6.64524
# [152]	validation-rmse:6.64505
# [153]	validation-rmse:6.64529
# [154]	validation-rmse:6.64512
# [155]	validation-rmse:6.64480
# [156]	validation-rmse:6.64472
# [157]	validation-rmse:6.64451
# [158]	validation-rmse:6.64429
# [159]	validation-rmse:6.64443
# [160]	validation-rmse:6.64419
# [161]	validation-rmse:6.64390
# [162]	validation-rmse:6.64372
# [163]	validation-rmse:6.64404
# [164]	validation-rmse:6.64382
# [165]	validation-rmse:6.64357
# [166]	validation-rmse:6.64320
# [167]	validation-rmse:6.64322
# [168]	validation-rmse:6.64307
# [169]	validation-rmse:6.64322
# [170]	validation-rmse:6.64341
# [171]	validation-rmse:6.64323
# [172]	validation-rmse:6.64326
# [173]	validation-rmse:6.64316
# [174]	validation-rmse:6.64327
# [175]	validation-rmse:6.64262
# [176]	validation-rmse:6.64294
# [177]	validation-rmse:6.64267
# [178]	validation-rmse:6.64269
# [179]	validation-rmse:6.64270
# [180]	validation-rmse:6.64277
# [181]	validation-rmse:6.64268
# [182]	validation-rmse:6.64249
# [183]	validation-rmse:6.64264
# [184]	validation-rmse:6.64270
# [185]	validation-rmse:6.64242
# [186]	validation-rmse:6.64260
# [187]	validation-rmse:6.64277
# [188]	validation-rmse:6.64261
# [189]	validation-rmse:6.64284
# [190]	validation-rmse:6.64267
# [191]	validation-rmse:6.64279
# [192]	validation-rmse:6.64259
#  18%|█▊        | 9/50 [16:54<1:17:03, 112.76s/trial, best loss: 6.331407493010902]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 34
#      22     return {'loss':rmse_val,'status':STATUS_OK} # loss must be a string or a number
#      24 search_space = {
#      25 'max_depth': scope.int(hp.quniform('max_depth',4,100,1)),
#      26 'learning_rate': hp.loguniform('learning_rate',-3,0), # [exp(-3), exp(0)], which is [0.05, 1]
#    (...)
#      31 'seed':42
#      32 }
# ---> 34 best_result = fmin(
#      35     fn=objective,
#      36     space=search_space,
#      37     algo=tpe.suggest,
#      38     max_evals=50,
#      39     trials=Trials()
#      40
#      41 )
#
# File /opt/conda/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File /opt/conda/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File /opt/conda/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File /opt/conda/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File /opt/conda/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File /opt/conda/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File /opt/conda/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[18], line 5, in objective(params)
#       3 mlflow.set_tag("model","xgboost")
#       4 mlflow.log_params(params)
# ----> 5 booster = xgb.train(
#       6     params=params,
#       7     dtrain=train,
#       8     num_boost_round=1000,
#       9     evals=[(valid,"validation")],
#      10     early_stopping_rounds=50
#      11 )
#      12 y_pred=booster.predict(train)
#      13 y_val_pred=booster.predict(valid)
#
# File /opt/conda/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File /opt/conda/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py:182, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     180         break
#     181     bst.update(dtrain, iteration=i, fobj=obj)
# --> 182     if cb_container.after_iteration(bst, i, dtrain, evals):
#     183         break
#     185 bst = cb_container.after_training(bst)
#
# File /opt/conda/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py:258, in CallbackContainer.after_iteration(self, model, epoch, dtrain, evals)
#     256 for _, name in evals:
#     257     assert name.find("-") == -1, "Dataset name should not contain `-`"
# --> 258 score: str = model.eval_set(evals, epoch, self.metric, self._output_margin)
#     259 metric_score = _parse_eval_str(score)
#     260 self._update_history(metric_score, epoch)
#
# File /opt/conda/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:2212, in Booster.eval_set(self, evals, iteration, feval, output_margin)
#    2209 evnames = c_array(ctypes.c_char_p, [c_str(d[1]) for d in evals])
#    2210 msg = ctypes.c_char_p()
#    2211 _check_call(
# -> 2212     _LIB.XGBoosterEvalOneIter(
#    2213         self.handle,
#    2214         ctypes.c_int(iteration),
#    2215         dmats,
#    2216         evnames,
#    2217         c_bst_ulong(len(evals)),
#    2218         ctypes.byref(msg),
#    2219     )
#    2220 )
#    2221 assert msg.value is not None
#    2222 res = msg.value.decode()  # pylint: disable=no-member
#
# KeyboardInterrupt:

# %%
# best model selection -- based on metric (rmse in this case), modeling time (duration), training size (max_depth) etc.

# mlflow autolog --- take one run as an example
# certain libraries support autologging
# xgboost is one of them

params = {
        'learning_rate':
        0.20472169880371677,
        'max_depth':
        17,
        'min_child_weight':
        1.2402611720043835,
        'objective':'reg:squarederror', # reg:linear is deprecated
        #'reg:linear',
        'reg_alpha':
        0.28567896734700793,
        'reg_lambda':
        0.004264404814393109,
        'seed':
        42,
        'eval_metric':'rmse', 
        'verbosity':1
}

with mlflow.start_run(): # use this 'wrapper' to ensure run artifacts and metadata are recorded
    booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=100, # triggers crashes
            evals=[(valid,"validation")],
            early_stopping_rounds=10 # instead of 50, which is used by the instructor
        )
# Out:
# [0]	validation-rmse:10.62105
# [1]	validation-rmse:9.45454
# [2]	validation-rmse:8.61244
# [3]	validation-rmse:8.02161
# [4]	validation-rmse:7.60613
# [5]	validation-rmse:7.31430
# [6]	validation-rmse:7.11506
# [7]	validation-rmse:6.97578
# [8]	validation-rmse:6.87711
# [9]	validation-rmse:6.80659
# [10]	validation-rmse:6.75482
# [11]	validation-rmse:6.71870
# [12]	validation-rmse:6.68975
# [13]	validation-rmse:6.67024
# [14]	validation-rmse:6.65272
# [15]	validation-rmse:6.63910
# [16]	validation-rmse:6.62823
# [17]	validation-rmse:6.62004
# [18]	validation-rmse:6.61336
# [19]	validation-rmse:6.60866
# [20]	validation-rmse:6.60602
# [21]	validation-rmse:6.60323
# [22]	validation-rmse:6.60192
# [23]	validation-rmse:6.60053
# [24]	validation-rmse:6.59835
# [25]	validation-rmse:6.59609
# [26]	validation-rmse:6.59387
# [27]	validation-rmse:6.59214
# [28]	validation-rmse:6.59088
# [29]	validation-rmse:6.58932
# [30]	validation-rmse:6.58731
# [31]	validation-rmse:6.58478
# [32]	validation-rmse:6.58333
# [33]	validation-rmse:6.58150
# [34]	validation-rmse:6.58088
# [35]	validation-rmse:6.57879
# [36]	validation-rmse:6.57598
# [37]	validation-rmse:6.57468
# [38]	validation-rmse:6.57322
# [39]	validation-rmse:6.57211
# [40]	validation-rmse:6.57037
# [41]	validation-rmse:6.56877
# [42]	validation-rmse:6.56702
# [43]	validation-rmse:6.56595
# [44]	validation-rmse:6.56504
# [45]	validation-rmse:6.56348
# [46]	validation-rmse:6.56115
# [47]	validation-rmse:6.56019
# [48]	validation-rmse:6.55827
# [49]	validation-rmse:6.55669
# [50]	validation-rmse:6.55492
# [51]	validation-rmse:6.55379
# [52]	validation-rmse:6.55209
# [53]	validation-rmse:6.55101
# [54]	validation-rmse:6.55023
# [55]	validation-rmse:6.54914
# [56]	validation-rmse:6.54802
# [57]	validation-rmse:6.54716
# [58]	validation-rmse:6.54590
# [59]	validation-rmse:6.54522
# [60]	validation-rmse:6.54425
# [61]	validation-rmse:6.54323
# [62]	validation-rmse:6.54180
# [63]	validation-rmse:6.54056
# [64]	validation-rmse:6.53971
# [65]	validation-rmse:6.53864
# [66]	validation-rmse:6.53678
# [67]	validation-rmse:6.53580
# [68]	validation-rmse:6.53482
# [69]	validation-rmse:6.53400
# [70]	validation-rmse:6.53313
# [71]	validation-rmse:6.53220
# [72]	validation-rmse:6.53128
# [73]	validation-rmse:6.53065
# [74]	validation-rmse:6.52919
# [75]	validation-rmse:6.52846
# [76]	validation-rmse:6.52699
# [77]	validation-rmse:6.52607
# [78]	validation-rmse:6.52443
# [79]	validation-rmse:6.52382
# [80]	validation-rmse:6.52274
# [81]	validation-rmse:6.52139
# [82]	validation-rmse:6.52069
# [83]	validation-rmse:6.52005
# [84]	validation-rmse:6.51886
# [85]	validation-rmse:6.51847
# [86]	validation-rmse:6.51774
# [87]	validation-rmse:6.51643
# [88]	validation-rmse:6.51554
# [89]	validation-rmse:6.51480
# [90]	validation-rmse:6.51394
# [91]	validation-rmse:6.51304
# [92]	validation-rmse:6.51204
# [93]	validation-rmse:6.51105
# [94]	validation-rmse:6.50938
# [95]	validation-rmse:6.50858
# [96]	validation-rmse:6.50831
# [97]	validation-rmse:6.50735
# [98]	validation-rmse:6.50629
# [99]	validation-rmse:6.50543
# 2025/06/19 22:07:59 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/06/19 22:07:59 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/conda/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [22:07:59] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
